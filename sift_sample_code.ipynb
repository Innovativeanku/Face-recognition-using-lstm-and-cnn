# %% [markdown]
# <a href="https://colab.research.google.com/github/Innovativeanku/Face-recognition-using-lstm-and-cnn/blob/main/sift_sample_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

# %%
sift=cv2.SIFT_create()

# %%
bf=cv2.BFMatcher(cv2.NORM_L2,crossCheck=True)

# %%
img1=cv2.imread('/content/drive/MyDrive/org1.png')

# %%
img2=cv2.imread('/content/drive/MyDrive/for1.png')

# %%
img1=cv2.cvtColor(img1,cv2.COLOR_BGR2GRAY)
img2=cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)

# %%
keypoints_1,descriptors_1=sift.detectAndCompute(img1,None)
keypoints_2,descriptors_2=sift.detectAndCompute(img2,None)

# %%
matches=bf.match(descriptors_1,descriptors_2)
matches=sorted(match,key=lambda x:x.distance)

# %%
img3 = cv2.drawMatches(img1, keypoints_1, img2, keypoints_2, matches[:10], None, flags=2)

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(img3)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=1152x668>
# -1
